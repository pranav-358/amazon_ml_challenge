# %% [markdown]
# <a href="https://colab.research.google.com/github/pranav-358/amazon_ml_challenge/blob/main/ML_Warriors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q rapidfuzz tqdm
